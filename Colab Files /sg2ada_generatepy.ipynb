# %% [markdown]
# # Post-Training Operations

# %% [markdown]
# ### Import image data and model from Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/FYP_GAN/tfdata.zip" -d "/content/Data/"
# Out:
# Archive:  /content/drive/MyDrive/FYP_GAN/tfdata.zip
#   inflating: /content/Data/custom-r06.tfrecords
#   inflating: /content/Data/custom-r07.tfrecords
#   inflating: /content/Data/custom-r04.tfrecords
#   inflating: /content/Data/custom-r02.tfrecords
#   inflating: /content/Data/custom-r08.tfrecords
#   inflating: /content/Data/custom-r05.tfrecords
#   inflating: /content/Data/custom-r03.tfrecords

# %%
# !unzip "/content/drive/MyDrive/FYP_GAN/data256x256.zip" -d "/content/data256x256/"

# %%
# !unzip "/content/drive/MyDrive/FYP_GAN/stylegan_ada_lab.zip" -d "/content/Model/"
# Out:
# Archive:  /content/drive/MyDrive/FYP_GAN/stylegan_ada_lab.zip
#    creating: /content/Model/metrics/
#   inflating: /content/Model/metrics/precision_recall.py
#   inflating: /content/Model/metrics/linear_separability.py
#   inflating: /content/Model/metrics/frechet_inception_distance.py
#   inflating: /content/Model/metrics/__init__.py
#    creating: /content/Model/metrics/__pycache__/
#   inflating: /content/Model/metrics/__pycache__/metric_defaults.cpython-36.pyc
#   inflating: /content/Model/metrics/__pycache__/__init__.cpython-36.pyc
#   inflating: /content/Model/metrics/perceptual_path_length.py
#   inflating: /content/Model/metrics/metric_defaults.py
#   inflating: /content/Model/metrics/metric_base.py
#   inflating: /content/Model/metrics/inception_score.py
#   inflating: /content/Model/metrics/kernel_inception_distance.py
#   inflating: /content/Model/dataset_tool.py
#   inflating: /content/Model/style_mixing.py
#   inflating: /content/Model/generate.py
# ...

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# ### Generate metrics for network snapshot

# %%
# !python /content/Model/calc_metrics.py --metricdata=/content/Data --mirror=1 --metrics=pr50k3_full \
    --network=/content/drive/MyDrive/FYP_GAN/networks/network-snapshot-008060.pkl
# Out:
# Loading network from "/content/drive/MyDrive/FYP_GAN/networks/network-snapshot-008060.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
#
# Gs                            Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# G_mapping/Normalize           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Dense2              262656    (?, 512)            (512, 512)
# G_mapping/Dense3              262656    (?, 512)            (512, 512)
# G_mapping/Dense4              262656    (?, 512)            (512, 512)
# ...

# %% [markdown]
# ### Generate seeds from network snapshot

# %%
# !python /content/Model/generate.py --outdir=collection7860 --trunc=1 --seeds=0-1000 \
    --network=/content/drive/MyDrive/FYP_GAN/network-snapshot-007560.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/FYP_GAN/network-snapshot-007560.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Generating image for seed 0 (0/1001) ...
# Generating image for seed 1 (1/1001) ...
# Generating image for seed 2 (2/1001) ...
# Generating image for seed 3 (3/1001) ...
# Generating image for seed 4 (4/1001) ...
# Generating image for seed 5 (5/1001) ...
# Generating image for seed 6 (6/1001) ...
# Generating image for seed 7 (7/1001) ...
# Generating image for seed 8 (8/1001) ...
# Generating image for seed 9 (9/1001) ...
# Generating image for seed 10 (10/1001) ...
# Generating image for seed 11 (11/1001) ...
# Generating image for seed 12 (12/1001) ...
# Generating image for seed 13 (13/1001) ...
# Generating image for seed 14 (14/1001) ...
# Generating image for seed 15 (15/1001) ...
# Generating image for seed 16 (16/1001) ...
# ...

# %%
# !zip -r /content/collection7560.zip /content/collection7860/
# Out:
#   adding: content/collection7860/ (stored 0%)
#   adding: content/collection7860/seed0475.png (deflated 0%)
#   adding: content/collection7860/seed0060.png (deflated 0%)
#   adding: content/collection7860/seed0757.png (deflated 0%)
#   adding: content/collection7860/seed0020.png (deflated 0%)
#   adding: content/collection7860/seed0662.png (deflated 0%)
#   adding: content/collection7860/seed0782.png (deflated 0%)
#   adding: content/collection7860/seed0871.png (deflated 0%)
#   adding: content/collection7860/seed0097.png (deflated 0%)
#   adding: content/collection7860/seed0793.png (deflated 0%)
#   adding: content/collection7860/seed0159.png (deflated 0%)
#   adding: content/collection7860/seed0885.png (deflated 0%)
#   adding: content/collection7860/seed0964.png (deflated 0%)
#   adding: content/collection7860/seed0472.png (deflated 0%)
#   adding: content/collection7860/seed0444.png (deflated 0%)
#   adding: content/collection7860/seed0883.png (deflated 0%)
# ...

# %%
from google.colab import files
files.download("/content/collection7560.zip")

# %%
# !python /content/Model/projector.py --outdir=out --target="/content/Screenshot 2021-03-17 at 16.35.35.png" \
    --network=/content/drive/MyDrive/FYP_GAN/network-snapshot-000360.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/FYP_GAN/network-snapshot-000360.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Loading... Done.
# Projector: Computing W midpoint and stddev using 10000 samples...
# Projector: std = 4.27577
# Projector: Setting up noise inputs...
# Projector: Building image output graph...
# Projector: Building loss graph...
# Projector: Building noise regularization graph...
# Projector: Setting up optimizer...
# Projector: Preparing target images...
# Projector: Initializing optimization state...
# 100% 1000/1000 [05:36<00:00,  2.97it/s, dist=0.1108, loss=0.11]
